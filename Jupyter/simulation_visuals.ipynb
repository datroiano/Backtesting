# %%
import pandas as pd

from UseFunctions.matplot import plot_graphs
from OptionClasses.Earnings.lookup import sims, errors
from MachineLearning.conversion import filter_stock_basis

x = filter_stock_basis(sims, movement_maximum=0.2)
plot_graphs(x)

# %%
x.corr().iloc[2]
# Out:
# entry_time                         0.002861
# exit_time                          0.108002
# strategy_profit_percent            1.000000
# stock_linear_correlated_measure   -0.030967
# Name: strategy_profit_percent, dtype: float64

# %%
len(x)
# Out:
# 255078

# %%
from OptionClasses.Strategies.straddle import StraddleStrategy

StraddleStrategy.get_meta_data_not_dollars(x)
# Out:
#                                             Metric     Value
# 0                Average Strategy Profit (Percent)  0.028924
# 1  Standard Deviation of Strategy Profit (Percent)  0.068265
# 2                                         Win Rate  0.700605
# 3                Maximum Strategy Profit (Percent)  0.394737
# 4                Minimum Strategy Profit (Percent) -0.169492
# 5                                     Sharpe Ratio  0.423703

# %%
pd.DataFrame(errors)
# Out:
#    ticker                     error
# 0      fb  Earnings Calendar Search
# 1     brk  Earnings Calendar Search
# 2    adbe  Earnings Calendar Search
# 3     bud  Earnings Calendar Search
# 4    twtr  Earnings Calendar Search
# 5     tsm  Earnings Calendar Search
# 6      mt  Earnings Calendar Search
# 7     bud  Earnings Calendar Search
# 8      fb  Earnings Calendar Search
# 9     brk  Earnings Calendar Search
# 10   adbe  Earnings Calendar Search
# 11    bud  Earnings Calendar Search
# 12   twtr  Earnings Calendar Search
# 13    tsm  Earnings Calendar Search
# 14     mt  Earnings Calendar Search
# 15     HD           TypeError Stock
# 16    WMT           TypeError Stock
# 17    MDT           TypeError Stock
# 18     HD           TypeError Stock
# 19    WMT           TypeError Stock
# 20    MDT           TypeError Stock
# 21    ACB         KeyError Strategy
# 22    HPE         KeyError Strategy
# 23      K         KeyError Strategy
# 24   MNST         KeyError Strategy
# 25      K         KeyError Strategy
# 26   MNST         KeyError Strategy
# 27      K         KeyError Strategy
# 28    ACB         KeyError Strategy
# 29    HPE         KeyError Strategy
# 30      K         KeyError Strategy
# 31   MNST         KeyError Strategy
# 32      K         KeyError Strategy
