# %%
import pandas as pd

from UseFunctions.matplot import plot_graphs
from OptionClasses.Earnings.sim_runner import sims, errors, tested
from MachineLearning.conversion import filter_stock_basis

x = filter_stock_basis(sims, movement_maximum=0.2)
plot_graphs(x)

# %%
from OptionClasses.Strategies.straddle import StraddleStrategy

StraddleStrategy.get_meta_data_not_dollars(x)
# Out:
#                                             Metric     Value
# 0                Average Strategy Profit (Percent) -0.006293
# 1  Standard Deviation of Strategy Profit (Percent)  0.059576
# 2                                         Win Rate  0.325096
# 3                Maximum Strategy Profit (Percent)  0.181818
# 4                Minimum Strategy Profit (Percent) -0.109694
# 5                                     Sharpe Ratio -0.105636

# %%
x.corr().iloc[2]
# Out:
# entry_time                         0.096889
# exit_time                         -0.068409
# strategy_profit_percent            1.000000
# stock_linear_correlated_measure    0.038154
# Name: strategy_profit_percent, dtype: float64

# %%
len(x)
# Out:
# 5220

# %%
pd.DataFrame(tested)
# Out:
#   ticker  trade_date  strike  expiration
# 0     VZ  2024-01-22    39.5  2024-01-26
# 1   AAPL  2024-02-01   185.0  2024-02-02
# 2   MSFT  2024-01-22   395.0  2024-01-26

# %%
pd.DataFrame(errors)
# Out:
#    ticker                     error
# 0  PLUGIN  Earnings Calendar Search
