# %%
import pandas as pd

from UseFunctions.matplot import plot_graphs
from OptionClasses.Earnings.lookup import sims, errors
from MachineLearning.conversion import filter_stock_basis

x = filter_stock_basis(sims, movement_maximum=0.2)
plot_graphs(x)

# %%
x.corr().iloc[2]
# Out:
# entry_time                         0.144387
# exit_time                         -0.195992
# strategy_profit_percent            1.000000
# stock_linear_correlated_measure   -0.624137
# Name: strategy_profit_percent, dtype: float64

# %%
len(x)
# Out:
# 3660

# %%
from OptionClasses.Strategies.straddle import StraddleStrategy

StraddleStrategy.get_meta_data_not_dollars(x)
# Out:
#                                             Metric     Value
# 0                Average Strategy Profit (Percent) -0.053971
# 1  Standard Deviation of Strategy Profit (Percent)  0.043814
# 2                                         Win Rate  0.037432
# 3                Maximum Strategy Profit (Percent)  0.011544
# 4                Minimum Strategy Profit (Percent) -0.136022
# 5                                     Sharpe Ratio -1.231829

# %%
pd.DataFrame(errors)
# Out:
#   ticker              error
# 0    NOV  KeyError Strategy
