# %%
import pandas as pd

from UseFunctions.matplot import plot_graphs
from OptionClasses.Earnings.sim_runner import sims, errors, tested
from MachineLearning.conversion import filter_stock_basis

x = filter_stock_basis(sims, movement_maximum=0.4)
plot_graphs(x)

# %%
from OptionClasses.Strategies.straddle import StraddleStrategy

StraddleStrategy.get_meta_data_not_dollars(x)
# Out:
#                                             Metric     Value
# 0                Average Strategy Profit (Percent)  0.014455
# 1  Standard Deviation of Strategy Profit (Percent)  0.067046
# 2                                         Win Rate  0.597280
# 3                Maximum Strategy Profit (Percent)  0.351064
# 4                Minimum Strategy Profit (Percent) -0.251318
# 5                                     Sharpe Ratio  0.215600

# %%
x.corr().iloc[2]
# Out:
# entry_time                        -0.018512
# exit_time                          0.065366
# strategy_profit_percent            1.000000
# stock_linear_correlated_measure    0.064329
# Name: strategy_profit_percent, dtype: float64

# %%
len(x)
# Out:
# 189166

# %%
pd.DataFrame(tested)
# Out:
#     ticker  trade_date  strike  expiration
# 0      UNH  2024-04-15   445.0  2024-04-19
# 1       MA  2024-04-30   455.0  2024-05-03
# 2      AXP  2024-04-18   220.0  2024-04-19
# 3      ABT  2024-04-16   109.0  2024-04-19
# 4      LUV  2024-04-24    29.0  2024-04-26
# ..     ...         ...     ...         ...
# 129    NOC  2024-04-24   472.5  2024-04-26
# 130     EL  2024-04-30   148.0  2024-05-03
# 131    PFE  2024-04-30    25.5  2024-05-03
# 132   INTU  2024-05-23   670.0  2024-05-24
# 133   SCHW  2024-04-12    70.0  2024-04-19
#
# [134 rows x 4 columns]

# %%
pd.DataFrame(errors)
# Out:
#     ticker                     error
# 0     CTXS  Earnings Calendar Search
# 1       UA  Earnings Calendar Search
# 2     FISV  Earnings Calendar Search
# 3      FRC  Earnings Calendar Search
# 4     ALXN  Earnings Calendar Search
# ..     ...                       ...
# 155   LDOS         KeyError Strategy
# 156    IFF         KeyError Strategy
# 157    HCA         KeyError Strategy
# 158    CHD         KeyError Strategy
# 159    AWK         KeyError Strategy
#
# [160 rows x 2 columns]
