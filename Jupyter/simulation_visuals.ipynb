# %%
import pandas as pd

from UseFunctions.matplot import plot_graphs
from OptionClasses.Earnings.sim_runner import sims, errors, tested
from MachineLearning.conversion import filter_stock_basis

x = filter_stock_basis(sims, movement_maximum=0.2)
plot_graphs(x)

# %%
from OptionClasses.Strategies.straddle import StraddleStrategy

StraddleStrategy.get_meta_data_not_dollars(x)
# Out:
#                                             Metric     Value
# 0                Average Strategy Profit (Percent)  0.092521
# 1  Standard Deviation of Strategy Profit (Percent)  0.015603
# 2                                         Win Rate  1.000000
# 3                Maximum Strategy Profit (Percent)  0.151667
# 4                Minimum Strategy Profit (Percent)  0.054140
# 5                                     Sharpe Ratio  5.929670

# %%
x.corr().iloc[2]
# Out:
# entry_time                        -0.664550
# exit_time                          0.021879
# strategy_profit_percent            1.000000
# stock_linear_correlated_measure    0.475727
# Name: strategy_profit_percent, dtype: float64

# %%
len(x)
# Out:
# 1830

# %%
pd.DataFrame(tested)
# Out:
#   ticker  trade_date  strike  expiration
# 0   AAPL  2023-02-02     150  2023-02-03

# %%
pd.DataFrame(errors)
# Out:
#    ticker                     error
# 0  PLUGIN  Earnings Calendar Search
