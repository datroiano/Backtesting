# %%
import pandas as pd

from UseFunctions.matplot import plot_graphs
from OptionClasses.Earnings.sim_runner import sims, errors, tested
from MachineLearning.conversion import filter_stock_basis

x = filter_stock_basis(sims, movement_maximum=0.2)
plot_graphs(x)

# %%
x.corr().iloc[2]
# Out:
# entry_time                         0.056496
# exit_time                          0.112968
# strategy_profit_percent            1.000000
# stock_linear_correlated_measure   -0.033238
# Name: strategy_profit_percent, dtype: float64

# %%
len(x)
# Out:
# 61401

# %%
from OptionClasses.Strategies.straddle import StraddleStrategy

StraddleStrategy.get_meta_data_not_dollars(x)
# Out:
#                                             Metric     Value
# 0                Average Strategy Profit (Percent)  0.029837
# 1  Standard Deviation of Strategy Profit (Percent)  0.054448
# 2                                         Win Rate  0.720086
# 3                Maximum Strategy Profit (Percent)  0.266355
# 4                Minimum Strategy Profit (Percent) -0.127563
# 5                                     Sharpe Ratio  0.547994

# %%
pd.DataFrame(tested)
# Out:
#    ticker  trade_date  strike  expiration
# 0       T  2024-01-23    17.0  2024-01-26
# 1     PFE  2024-01-29    27.5  2024-02-02
# 2    BABA  2024-02-06    77.0  2024-02-09
# 3    INTC  2024-01-25    49.5  2024-01-26
# 4    NCLH  2024-02-26    16.0  2024-03-01
# 5     NKE  2024-03-21   101.0  2024-03-22
# 6     CAT  2024-02-02   310.0  2024-02-09
# 7     CRM  2024-02-28   300.0  2024-03-01
# 8   CMCSA  2024-01-24    43.5  2024-01-26
# 9      KO  2024-02-12    59.0  2024-02-16
# 10   NFLX  2024-01-23   487.5  2024-01-26
# 11     MA  2024-01-30   442.5  2024-02-02
# 12    AMD  2024-01-30   177.5  2024-02-02
# 13   ORCL  2024-03-11   114.0  2024-03-15
# 14    MRK  2024-01-31   122.0  2024-02-02
# 15   AMZN  2024-02-01   157.5  2024-02-02
# 16      V  2024-01-25   272.5  2024-01-26
# 17    PEP  2024-02-08   172.5  2024-02-09
# 18    MCD  2024-02-02   295.0  2024-02-09
# 19    JPM  2024-01-11   170.0  2024-01-12
# 20     BA  2024-01-30   200.0  2024-02-02
# 21   MSFT  2024-01-30   410.0  2024-02-02
# 22   COST  2024-03-07   780.0  2024-03-08
# 23     VZ  2024-01-22    39.5  2024-01-26
# 24   ABBV  2024-02-01   165.0  2024-02-02
# 25    DIS  2024-02-07    99.0  2024-02-09
# 26    DHR  2024-01-29   230.0  2024-02-02
# 27   AMGN  2024-02-06   322.5  2024-02-09
# 28   GOOG  2024-01-30   155.0  2024-02-02
# 29    ABT  2024-01-23   114.0  2024-01-26
# 30    NOW  2024-01-24   770.0  2024-01-26
# 31   SBUX  2024-01-30    94.0  2024-02-02
# 32   TMUS  2024-01-25   162.5  2024-01-26
# 33    JNJ  2024-01-22   162.5  2024-01-26
# 34     PG  2024-01-22   148.0  2024-01-26
# 35    UNH  2024-01-11   537.5  2024-01-12
# 36   AAPL  2024-02-01   185.0  2024-02-02
# 37    HON  2024-01-31   205.0  2024-02-02

# %%
pd.DataFrame(errors)
# Out:
#    ticker                     error
# 0    TSLA  Earnings Calendar Search
# 1     TSM  Earnings Calendar Search
# 2     BRK  Earnings Calendar Search
# 3    TWTR  Earnings Calendar Search
# 4     AXP  Earnings Calendar Search
# 5    ADBE  Earnings Calendar Search
# 6     BUD  Earnings Calendar Search
# 7      FB  Earnings Calendar Search
# 8     WMT           TypeError Stock
# 9      HD           TypeError Stock
# 10    MDT           TypeError Stock
# 11    ACB         KeyError Strategy
